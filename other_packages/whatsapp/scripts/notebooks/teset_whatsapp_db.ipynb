# %%
from pathlib import Path
import sqlite3

# %%
SQLITE_DB_PATH = Path("~/Library/Group Containers/group.net.whatsapp.WhatsApp.shared/ChatStorage.sqlite").expanduser()
db = sqlite3.connect(str(SQLITE_DB_PATH))

# %%
start_of_week_str
# Out:
# '2025-07-14 00:00:00'

# %%
from datetime import datetime, timezone, timedelta

# Function: Seconds since Jan 1, 2001 UTC (WhatsApp/iOS epoch)
def get_timestamp_since_2001(dt):
    epoch_2001 = datetime(2001, 1, 1, tzinfo=timezone.utc)
    return int((dt - epoch_2001).total_seconds())

# Function: Convert WhatsApp timestamp to datetime
def whatsapp_timestamp_to_datetime(timestamp):
    epoch_2001 = datetime(2001, 1, 1, tzinfo=timezone.utc)
    return epoch_2001 + timedelta(seconds=timestamp)

now = datetime.now(timezone.utc)
start_of_week_date = (now - timedelta(days=now.weekday())).date()
start_of_week = datetime.combine(start_of_week_date, datetime.min.time(), tzinfo=timezone.utc)
start_of_week_timestamp = get_timestamp_since_2001(start_of_week)

# %%
start_of_week_timestamp
# Out:
# 774144000

# %%
import datetime

# Get the start of the current week (Monday)



query = """
SELECT
    ZWACHATSESSION.ZCONTACTJID as chat_jid,
    ZWAMESSAGE.ZTEXT as message_text,
    ZWAMESSAGE.ZMESSAGEDATE as message_date
FROM
    ZWACHATSESSION
JOIN
    ZWAMESSAGE ON ZWAMESSAGE.ZCHATSESSION = ZWACHATSESSION.Z_PK
WHERE
    ZWAMESSAGE.ZMESSAGEDATE >= ? -- WhatsApp stores dates as unix timestamps
ORDER BY
    chat_jid, message_date
"""

# WhatsApp's ZMESSAGEDATE is often in Mac absolute time (seconds since 2001-01-01)
# If so, you may need to adjust the query and conversion accordingly.
# For now, let's assume it's unix time (seconds since 1970-01-01).
# If not, you may need to add (strftime('%s', ?) - strftime('%s', '2001-01-01 00:00:00')) to convert.

cursor = db.cursor()
cursor.execute(query, (start_of_week_timestamp,))
results = cursor.fetchall()

# %%
len(results)
# Out:
# 301

# %%
from collections import defaultdict

channels = defaultdict(list)
for channel_name, message_text, message_date in results:
    channels[channel_name].append({
        "message_text": message_text,
        "message_date": message_date,
    })

for channel, messages in channels.items():
    if not messages:
        continue
    
    print(f"Channel: {channel}")
    for msg in messages:
        print(f"  [{msg['message_date']}] {msg['message_text']}")
    print("-" * 40)
# Out:
# Channel: 120363023426092133@g.us
#   [774282627.328522] None
# ----------------------------------------
# Channel: 120363023686310544@g.us
#   [774217309] Huh… What’s that smell? You feel it, Ieva?
#   [774217322] Hmmm what is it Alan?
#   [774217361] I don’t know, it smells like, AN EFFING COOL ROOFTOP SALSA PARTY AGAIN?!?!?!
#   [774217381] None
#   [774217448] Guess my senses were right!
#   [774223691] *LAST MINUTE CALL*  💃🏽🕺
#
# Who can join us for some dancing in The Hague today?!
#
# *Looking for 2 followers and 1 leader.*
#
# You can drive with us from A’dam Central Station or HQ, at 16:15!
#
# 🎈 *What’s the plan?*
# We’ll bring vibes, fun, and entertainment to a graduation evening at a school! Salsa dances, flashmob ruedas, maybe a merengue parade with the crowd…
#
# DJ Manga & Yunan will be there spinning the tunes with live percussion! 🪘🎶
#
# You don't have to be the best dancer or performer, if you enjoy creating a fun atmosphere and making people smile, you're EXACTLY who we need!
#
# 📆*Date:* 15 July
# 🕟*Time:* 17:30 till 20:30 (present in The Hague)
# 📍*Location:* ROC Mondriaan, Aspasialaan 19, The Hague
# https://maps.app.goo.gl/8MHWvQedZuWDNEW79?g_st=com.google.maps.preview.copy
#   [774228495] This event Willemijn just posted was very fun last Thursday! The vibe was good and it was a great opportunity to bond with the STG team ❤️❤️❤️
# Would recommend to go there if you can 🙌🙌🙌
#   [774265206] Tot straks 🥳🥳🥳
#   [774269634] Hey guys, I’m selling my ticket for Fiesta Macumba festival for €50,90. Cheaper than the ones available now. Send me a pm if interested 🪩💃🏼
# ----------------------------------------
# Channel: 120363041871528862@g.us
#   [774280169] None
# ----------------------------------------
# Channel: 120363048194225346@g.us
#   [774282625.874735] None
# ----------------------------------------
# Channel: 120363048792796299@g.us
#   [774282626.119472] None
# ----------------------------------------
# Channel: 120363193710642064@g.us
#   [774256299] Hoe laat vliegen we vrijdag?
#   [774257522] None
#   [774257771] Ze zijn oek bezig bij Schiphol, dus alles staat daar ook muurvast als het goed is
#   [774257971] Ja is dat su? Mutten we wel even rekening mee houden dus
#   [774259239] We kunnen even checken tegen die tijd op die schiphol drukte site
#   [774259260] None
#   [774259291] Ja dat moet vet slim zijn
#   [774259298] Die tijdslot boeken
#   [774259390] Ik kan niet mega vroeg op schiphol zijn, denk op zn vroegst 12.30 een beetje, en we vliegen 14.35
#   [774259454] Dat moet prima lukken denk ik ouwe!
#   [774280882] Heeft iemand van jullie een klein boxje?
#   [774280914] En hoe doen wij het met vervoer uurtje of half 11 bij jou Galie?
#   [774281903] Kunnen misschien oek wel die van Leon of Pim lenen? Dat zou wel chill zijn. Mooi voor op ‘t dakterras
#   [774281941] Suiets is prima! Tussen 10:00 en 1030 vertrekken ofsu vanuit hier. Wie rijdt? En moeten we ook even parkeerplek fixen bij Schiphol?
#   [774282158] Yes, moeten even zo'n plekje vastleggen op een P. Rijden maakt mij niet uit. Ik rijd sowieso en pik M op, maar kan naar jou toerijden en daar de auto droppen of we pikken je op en rijden door naar Schiphol in m'n koekblikje
#   [774282740] Aai! Zou top zijn als we in jouw auto kunnen bro. As het die van ons nodig en de Polo staat dit weekend bij de garage.. Fix jij parkeerplek dan L?
#   [774282768] Zal ik ik nog even informeren naar die VIP meuk voor die zaterdag? Even horen of dat was is?
#   [774285625] Is goed ouwe! Dan gaan we in die van mij
#   [774285639] Oja, cool. Was ik alweer vergeten seun
#   [774285654] Hoor maar even wat ze te bieden hebben
#   [774286886] Komt goed!
# ----------------------------------------
# Channel: 120363400344994257@g.us
#   [774177731] None
#   [774177731] None
#   [774177731] 40757051062@s.whatsapp.net
#   [774178164] Hi Mihai, meet Koen who is working on the productivity agent I mentioned. Koen, Mihai might be able to give a spin and share his thoughts and expertise (thanks!).
#
# Hope this is productive both ways, I'll let you find a time to chat 🙂
#   [774178418] Hey Mihai, nice to meet you! I am working on some mcp related tooling for devs and would love to get some feedback for it over a quick session in a call (other sessions roughly took 20-30 minutes). Would you be interested in that? I can try to find a time that works well for you this week if possible
#   [774194953] Hey both, thanks for the intro.
#
# Koen, sure, let’s have a chat about this. Can you please pick a time on antonmih.ai/meet ?
#   [774195505] Thanks! I booked for slot for this Wednesday. Quick question: are you on a mac, or something else?
#   [774200402] I’m on a mac
#   [774205755] perfect!
# ----------------------------------------
# Channel: 120363403286356897@g.us
#   [774219413] 31657536820@s.whatsapp.net
#   [774219413] 31657536820@s.whatsapp.net
#   [774224766] POM - principles over moves
#   [774224766] POM - principles over moves
#   [774225194] None
#   [774225194] None
#   [774225281] None
#   [774225281] None
#   [774225312] 257088202752193@lid
#   [774225312] 257088202752193@lid
#   [774225857] Good evening querides salseres! we happily announce: our first workshop is readyyyyyyyyy to come into action. Here are the details:
#
# *Bodymechanics & Styling Deepdive*
# What you will learn:
# the biomechanics of…
# - weightshift and weighttransfer
# - ⁠mobility and isolations
# - ⁠styling foundations
# Goal: to make your basic look more suave and set the foundations for being a light dancer in both roles
#
# Friday, 25th of July  19.00 - 21.00
#
# Price: 19,50 (special price for special people and special first time occasion 🥳)
#   [774225857] Good evening querides salseres! we happily announce: our first workshop is readyyyyyyyyy to come into action. Here are the details:
#
# *Bodymechanics & Styling Deepdive*
# What you will learn:
# the biomechanics of…
# - weightshift and weighttransfer
# - ⁠mobility and isolations
# - ⁠styling foundations
# Goal: to make your basic look more suave and set the foundations for being a light dancer in both roles
#
# Friday, 25th of July  19.00 - 21.00
#
# Price: 19,50 (special price for special people and special first time occasion 🥳)
#   [774226104] 🙏 Please pay € 19.50 for "POM 25.7." through https://bunq.me/o/ixBUwDkcezyFk7E0LqCWl
#   [774226104] 🙏 Please pay € 19.50 for "POM 25.7." through https://bunq.me/o/ixBUwDkcezyFk7E0LqCWl
#   [774226154] You can pay here, please leave a 💸 once you've paid
#   [774226154] You can pay here, please leave a 💸 once you've paid
#   [774226242] Location: CREA studio zaal 4.02
#   [774226242] Location: CREA studio zaal 4.02
#   [774226545] 💸
#   [774226545] 💸
#   [774228311] please leave your flying money emoji here as a reaction so we have it all in one place. studio has limited capacity and we want to be able to give feedback aswell 😋
#   [774228311] please leave your flying money emoji here as a reaction so we have it all in one place. studio has limited capacity and we want to be able to give feedback aswell 😋
#   [774228757] NOTE: this is not a Salsa Te Gusta Activity. We can teach outside of Te Gusta if the classes do not directly compare to what salsa te gusta offers. So that is everything that's not a partnerwork course based on teaching figure sequences. Arie and I have spend a loooooot of money and time to become the dancers we are today and we just love to nerd out on biomechanics and technique and want to be creative with it. So many more workshop ideas to come to life, also with other collaborators. I am excited 🤩
#   [774228757] NOTE: this is not a Salsa Te Gusta Activity. We can teach outside of Te Gusta if the classes do not directly compare to what salsa te gusta offers. So that is everything that's not a partnerwork course based on teaching figure sequences. Arie and I have spend a loooooot of money and time to become the dancers we are today and we just love to nerd out on biomechanics and technique and want to be creative with it. So many more workshop ideas to come to life, also with other collaborators. I am excited 🤩
#   [774228791] Feel free to invite other people you think would love to join:
#   [774228791] Feel free to invite other people you think would love to join:
#   [774228892] https://chat.whatsapp.com/GUKkA7p6EnG71HFqMlYhlu?mode=r_t
#   [774228892] https://chat.whatsapp.com/GUKkA7p6EnG71HFqMlYhlu?mode=r_t
#   [774229515] 257088202752193@lid
#   [774229515] 257088202752193@lid
#   [774239264] None
#   [774239264] None
#   [774251615] Unfortunately I’m on holiday the 25th
# Have fun 💃 🕺
#   [774251615] Unfortunately I’m on holiday the 25th
# Have fun 💃 🕺
#   [774252214] Thanks for the invite! ❤ I can't make it to this workshop bc of holidays but I'll happy follow to check out the next
#   [774252214] Thanks for the invite! ❤ I can't make it to this workshop bc of holidays but I'll happy follow to check out the next
#   [774252755] Same here!! 🫠 next time I would love to join!
#   [774252755] Same here!! 🫠 next time I would love to join!
#   [774254611] Also hoping to be able to join next time🤸
#   [774254611] Also hoping to be able to join next time🤸
#   [774255666] Same for me! Hopefully next time 💃
#   [774258333] Same! Excited for next time!
#   [774260055] None
#   [774263341] None
#   [774264980] None
#   [774265956] None
#   [774266015] 119228359290928@lid
#   [774268215] None
#   [774268359] Welcome to the new people! Can you all see the post on the first workshop and the ticket/bank link?
#
# It's also in the description of the group.🫶🏼
#   [774268443] 257088202752193@lid
#   [774268469] None
#   [774268511] None
#   [774268534] I would also love to join but I’m probably also on vacation then! Hopefully next time 😊
#   [774268614] None
#   [774271621] None
# ----------------------------------------
# Channel: 120363418741893104@g.us
#   [774174698] None
#   [774174698] None
#   [774174698] 40757051062@s.whatsapp.net
#   [774174698] None
#   [774174698] 40757051062@s.whatsapp.net
#   [774174698] None
#   [774174720] Hey both!
#
# Andrei, I'd like to introduce you to Koen who's building the productivity agent
#
# Koen, meet Andrei, who’s excited to give it a spin (thanks!!)
#
# Hope this is productive both ways, I'll let you find a time to chat :D
#   [774174720] Hey both!
#
# Andrei, I'd like to introduce you to Koen who's building the productivity agent
#
# Koen, meet Andrei, who’s excited to give it a spin (thanks!!)
#
# Hope this is productive both ways, I'll let you find a time to chat :D
#   [774178438] Hey Andrei, nice to meet you! I am working on some mcp related tooling for devs and would love to get some feedback for it over a quick session in a call (other sessions roughly took 20-30 minutes). Would you be interested in that? I can try to find a time that works well for you this week if possible
#   [774178438] Hey Andrei, nice to meet you! I am working on some mcp related tooling for devs and would love to get some feedback for it over a quick session in a call (other sessions roughly took 20-30 minutes). Would you be interested in that? I can try to find a time that works well for you this week if possible
#   [774178610] Hi Koen! Happy to help!
#   [774178610] Hi Koen! Happy to help!
#   [774178680] I'm available today after 4pm UK time.
#   [774178701] If that doesn't work, I'll come back with more time slots.
#   [774178737] yes that works, how about 16.15 UK time?
#   [774178760] Perfect timing
#   [774178772] awesome! Can you share your email so I can send an invite?
#   [774178786] mail@andreibratu.com
#   [774178916] thanks andrei, invite sent!
#   [774182521] @31681216185 hey, the invite you sent is for 15:15 UK time. I have an interview during that hour, can we move it to 16:15?
#   [774182545] ah my bad, apologies
#   [774182547] changing now
#   [774182564] updated
#   [774195360] Hey Andrei, quick check: Are you using an apple machine or something else?
#   [774198321] Yes, apple machine
#   [774212184] @40772175241 I just found out I forgot to push a bunch of fixes for problems you encountered. If you find time would you be willing to run the following things
#
# git pull
# tb reset # this removes the transcriptions
# tb install meeting-notes-mcp
# # wait for 20/30 seconds (just to be sure)
# tb show meetings-notes-mcp
# # could you check now if you again see at least 1 transcription?
#
# If you dont find the time no worries, thanks a lot for your patience today!
#   [774266486] Heya, I'll give it a try today
# ----------------------------------------
# Channel: 12393609060@s.whatsapp.net
#   [774282627.5420231] None
#   [774286457.6915181] None
# ----------------------------------------
# Channel: 12494666622@s.whatsapp.net
#   [774286457.695725] None
# ----------------------------------------
# Channel: 12729221382@s.whatsapp.net
#   [774286457.69459] None
# ----------------------------------------
# Channel: 1527146235@broadcast
#   [774282602.313548] None
# ----------------------------------------
# Channel: 15417221526@s.whatsapp.net
#   [774286457.694981] None
# ----------------------------------------
# Channel: 18149354042-1575509010@g.us
#   [774282626.928849] None
# ----------------------------------------
# Channel: 31206490787@s.whatsapp.net
#   [774282627.5629901] None
# ----------------------------------------
# Channel: 31612912260-1372966421@g.us
#   [774175048] Koen, Pim en Steve jullie nog kosten gemaakt?
#   [774175084] Ja ik zal het even noteren is maar 3 of 4 uitgaven volgens mij
#   [774175558] Ja, doe het zo even
#   [774255923] None
#   [774255923] None
#   [774256015] Met het voorschot van €600 pp komen we dan op €975 totaal per person, dat is niet gek voor een weekendje Lissabon zonder Lissabon te hebben gezien! Bedankt en tot volgend jaar!
#   [774256210] Wil je mij alsjeblieft betalen voor 'Lissabon' via https://tikkie.me/pay/6e283b94rr5mlk89ednr
#
# Deze link is geldig t/m 29 juli
#   [774256418] Top man, bedankt voor het fixen Peerd en Oepie. Mooi weekendje!
#   [774257626] Was top boys! Keurig regelt ❤️
#   [774257815] None
#   [774257815] None
#   [774257822] Succes jongens
#   [774260143] Hahaha donders. Binnen jum Mallorca alweer vergeten😜
#   [774260405] 😂😂
#   [774260585] Bij gebrek aan tijd door beginnend vaderschap mag er eventueel geruild worden. Maar moet zeggen dat Patrick en Ik er weinig tijd aan kwijt waren.
#   [774261074] Hahah nee komt goed hoor 💪
#   [774261777] None
# ----------------------------------------
# Channel: 31621895921@s.whatsapp.net
#   [774277037] wil je nog ergo vanmiddag? Ik kan niet heel laart
#   [774277038] laat
#   [774280944] Even kijken hoe laat klaar
#   [774280951] Denk dat ik rond 1830-19 kan
#   [774280970] ik ga 18.15 op zn laatst
#   [774288587] Ik pak nu mijn spullen
# ----------------------------------------
# Channel: 31623127797@s.whatsapp.net
#   [774179641] sorry duurde even. Heb in totaal 925 uitgegeven
# https://docs.google.com/spreadsheets/d/1_Inpmb_6qSUB2pMbrUkJsJN2d-mRrhwTS_uAP8KQ7AA/edit?gid=0#gid=0
# ----------------------------------------
# Channel: 31623232990@s.whatsapp.net
#   [774171147] https://open.spotify.com/track/3OHvE9wWkFDd3m7iAG7YRO?si=JDJ1PUokTsC2PUHNWdt4_Q
#   [774171147] https://open.spotify.com/track/3OHvE9wWkFDd3m7iAG7YRO?si=JDJ1PUokTsC2PUHNWdt4_Q
#   [774171161] Deze stonden vorig jaar op de Parade, was ook echt hilarisch
#   [774171161] Deze stonden vorig jaar op de Parade, was ook echt hilarisch
#   [774179884] klinkt ook leuk!
#   [774179884] klinkt ook leuk!
#   [774179904] beetje spinvisesque
#   [774179904] beetje spinvisesque
#   [774179909] maar dan brabo versie
#   [774179909] maar dan brabo versie
#   [774179933] ken je dikke jenny van nereus?
#   [774179933] ken je dikke jenny van nereus?
#   [774179952] Ja was top, gehuild van het lachen
#   [774179952] Ja was top, gehuild van het lachen
#   [774179960] Zij komen ook op lowlands!
#   [774179960] Zij komen ook op lowlands!
#   [774179964] Haha nee?
#   [774179964] Haha nee?
#   [774179967] Vertel
#   [774179967] Vertel
#   [774179983] ja echt een kut wijf is dat
#   [774179983] ja echt een kut wijf is dat
#   [774180005] jenny van dobben debruijn
#   [774180005] jenny van dobben debruijn
#   [774180021] het vrouewelijke ergo kannon van 10 jaar geleden
#   [774180021] het vrouewelijke ergo kannon van 10 jaar geleden
#   [774180052] maar wel geinig dat er dus meerdere dikke jennies zijn
#   [774180052] maar wel geinig dat er dus meerdere dikke jennies zijn
#   [774180079] of misschien gaat het wel over dè jenny
#   [774180079] of misschien gaat het wel over dè jenny
#   [774180162] Oh jeetje, de naam past wel bij der dan
#   [774180162] Oh jeetje, de naam past wel bij der dan
#   [774180175] Te veel kroketjes gegeten
#   [774180175] Te veel kroketjes gegeten
#   [774180185] Oeh wie weet
#   [774180185] Oeh wie weet
#   [774180223] ja met kroketjes kwam je er niet helemaal met jenny hoor, dit was meer categorie frituurvet atten
#   [774180223] ja met kroketjes kwam je er niet helemaal met jenny hoor, dit was meer categorie frituurvet atten
#   [774180269] 😂😂
#   [774180269] 😂😂
#   [774180281] Dat zij ooit lid mocht worden van nereus
#   [774180281] Dat zij ooit lid mocht worden van nereus
#   [774180289] Ik dacht alleen knappe dunne lange mensen
#   [774180289] Ik dacht alleen knappe dunne lange mensen
#   [774180693] ja ze heeft zich helemaal ingesmeerd in olie, en zo is ze er tussendoor geglipt
#   [774180693] ja ze heeft zich helemaal ingesmeerd in olie, en zo is ze er tussendoor geglipt
#   [774182717] hahahah
#   [774182717] hahahah
#   [774182815] None
#   [774182815] None
#   [774183122] None
#   [774183122] None
#   [774183741] None
#   [774183741] None
#   [774185844] nice!
#   [774185844] nice!
#   [774186071] bilbao klinkt ook wel echt goed
#   [774186071] bilbao klinkt ook wel echt goed
#   [774191603] Oh en qua planning deze week, ik heb morgen alleen padel meteen uit werk, maar woensdag en donderdag met vriendinnen afgesproken
#   [774191603] Oh en qua planning deze week, ik heb morgen alleen padel meteen uit werk, maar woensdag en donderdag met vriendinnen afgesproken
#   [774191648] Excusez moi voor mijn overload aan appjes vandaag 🙃
#   [774191648] Excusez moi voor mijn overload aan appjes vandaag 🙃
#   [774192060] ik vind het wel gezellig hoor
#   [774192060] ik vind het wel gezellig hoor
#   [774192116] moet even checken qua sporten maar ik kan sowieso daarna wel
#   [774192116] moet even checken qua sporten maar ik kan sowieso daarna wel
#   [774192392] Gelukkig!
#   [774192392] Gelukkig!
#   [774192399] Laat maar weten!
#   [774192399] Laat maar weten!
#   [774210525] Oh en nog een vraag hihi
#   [774210525] Oh en nog een vraag hihi
#   [774210530] Wat doe je de 24ste?
#   [774210530] Wat doe je de 24ste?
#   [774211359] None
#   [774211359] None
#   [774211371] en die btw aangifte kan ook een dag eerder
#   [774211371] en die btw aangifte kan ook een dag eerder
#   [774211548] Kijk dat is top
#   [774211548] Kijk dat is top
#   [774211553] Heb je zin in een feestje?
#   [774211553] Heb je zin in een feestje?
#   [774211597] Ken je heineken afterwork?
#   [774211597] Ken je heineken afterwork?
#   [774211616] ja wel van gehoord
#   [774211616] ja wel van gehoord
#   [774211643] denk niet het beste moment na 4 dagen budapest, maar wel een leuk idee
#   [774211643] denk niet het beste moment na 4 dagen budapest, maar wel een leuk idee
#   [774211654] None
#   [774211654] None
#   [774211663] None
#   [774211663] None
#   [774211707] ja na dit spraakberichtje ben ik om
#   [774211707] ja na dit spraakberichtje ben ik om
#   [774211839] Wieeeehhh
#   [774211839] Wieeeehhh
#   [774211841] Leuk!
#   [774211841] Leuk!
#   [774211859] Ah dan ben je wrl weer hersteld haha
#   [774211859] Ah dan ben je wrl weer hersteld haha
#   [774262631] None
#   [774262631] None
#   [774264200] De kittelaar!
#   [774277202] gaat sowieso lukken vanavond. Op zn laatst 19.30 maar als ik eerder klaar ben app ik je even
#   [774277393] Nou wat gezellig!
#   [774277705] sarcasme?
#   [774277708] En dan eten samen?
#   [774277711] Nee haha
#   [774277717] ja samen eten!
#   [774277730] None
#   [774277747] jeetje, deze is nieuw voor mij
#   [774277820] Graag gedaan
#   [774277837] Culturele verrijking
#   [774281344] Waar willen we eten? Hier eet Fleur ook thuis
#   [774282144] geen voorkeur, deze staan ook nog op mij lijstje fyi
#
# https://www.google.com/maps/place/Testamatta+Ristorante+Enoteca/@52.3622204,4.8734135,16z/data=!4m10!1m2!2m1!1sitaliaans+restaurant+overtoom!3m6!1s0x47c60961794289c9:0x2bddaa9bc60a731f!8m2!3d52.3621246!4d4.8734791!-gEECAAQLA!16s%2Fg%2F11sv5nvf1y?entry=ttu&g_ep=EgoyMDI1MDcwOS4wIKXMDSoASAFQAw%3D%3D
#
# https://www.google.com/maps/place/Ku+Kitchen+%26+Bar/@52.3617002,4.8964185,16z/data=!3m1!4b1!4m6!3m5!1s0x47c609940dcdc5ff:0xc590b1043f43802f!8m2!3d52.3617002!4d4.8989934!16s%2Fg%2F11bbrkq6xq?entry=ttu&g_ep=EgoyMDI1MDcwOS4wIKXMDSoASAFQAw%3D%3D
# Bij ku ben ik al vaak geweest maar nog niet met jou
#   [774282333] jij wilde minder opties he
#   [774282334] niet meer
#   [774282675] Oeh heel lekker
#   [774282701] Heb wel meer zin in de 1e dan de 2e, alhoewel die er wel heerlijk uit ziet
#   [774282720] oke, pastaatje dan?
#   [774282879] Is goed!
#   [774282917] Heel vrel eerder dan 19:30 red ik trouwens ook niet
#   [774282983] oke, zal ik 8u reserveren voor de zekerheid?
#   [774283057] gedaan
#   [774283283] Topper ben je 🥰
# ----------------------------------------
# Channel: 31629261953@s.whatsapp.net
#   [774194902] I suppose you didnt find time, is 15 or 18 still an option?
#   [774253279] Hey Koen, I couldn't find time indeed. How about a call on 18th at 11am?
#   [774256867] None
#   [774257177] If you read my latest message, turns out I misread so never mind. Checking again now if that works
#   [774258922] Yes 11am works! Thanks!
# ----------------------------------------
# Channel: 31646084317@s.whatsapp.net
#   [774257239] Yo, kan je even de vluchttijden doorgeven? Moet ff weten voor werk
#   [774257420] Bro! Ik zal even kijken
#   [774257488] We vliegen 1435 heen vrijdag! 🙏
# ----------------------------------------
# Channel: 31646630022@s.whatsapp.net
#   [774253498] Ik ben zondag weer yhuis uit estland
#   [774253503] Ben wel bij rondje fietsen
#   [774253508] En happie eten
#   [774277002] ik ben vrijdag tot maandag in budapest
#   [774277009] dus laten we volgende weekd oen
# ----------------------------------------
# Channel: 31889911600@s.whatsapp.net
#   [774282627.476926] None
# ----------------------------------------
# Channel: 4915735992293@s.whatsapp.net
#   [774282627.497959] None
# ----------------------------------------
# Channel: 4917688800103@s.whatsapp.net
#   [774282627.4563221] None
# ----------------------------------------
# Channel: 493058872052@s.whatsapp.net
#   [774282627.518272] None
# ----------------------------------------
# Channel: 62838478051406@s.whatsapp.net
#   [774286457.695272] None
# ----------------------------------------
# Channel: 959677257984@s.whatsapp.net
#   [774286457.695498] None
# ----------------------------------------

# %%
cursor = db.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
for table_name_tuple in tables:
    table_name = table_name_tuple[0]
    print(f"Table: {table_name}")
    cursor.execute(f"PRAGMA table_info('{table_name}');")
    columns = cursor.fetchall()
    print("Columns:")
    for col in columns:
        print(f"  {col[1]} ({col[2]})")
    print("-" * 40)
# Out:
# Table: ZWABLACKLISTITEM
# Columns:
#   Z_PK (INTEGER)
#   Z_ENT (INTEGER)
#   Z_OPT (INTEGER)
#   ZJID (VARCHAR)
# ----------------------------------------
# Table: ZWACHATPROPERTIES
# Columns:
#   Z_PK (INTEGER)
#   Z_ENT (INTEGER)
#   Z_OPT (INTEGER)
#   ZALERTS (INTEGER)
#   ZENABLED (INTEGER)
#   ZCHATSESSION (INTEGER)
#   ZMUTEDATE (TIMESTAMP)
#   ZSOUNDNAME (VARCHAR)
# ----------------------------------------
# Table: ZWACHATPUSHCONFIG
# Columns:
#   Z_PK (INTEGER)
#   Z_ENT (INTEGER)
#   Z_OPT (INTEGER)
#   ZALERTS (INTEGER)
#   ZMUTEDUNTIL (TIMESTAMP)
#   ZJID (VARCHAR)
#   ZRINGTONE (VARCHAR)
#   ZSOUND (VARCHAR)
# ----------------------------------------
# Table: ZWACHATSESSION
# Columns:
#   Z_PK (INTEGER)
#   Z_ENT (INTEGER)
#   Z_OPT (INTEGER)
#   ZARCHIVED (INTEGER)
#   ZCONTACTABID (INTEGER)
#   ZFLAGS (INTEGER)
#   ZHIDDEN (INTEGER)
#   ZIDENTITYVERIFICATIONEPOCH (INTEGER)
#   ZIDENTITYVERIFICATIONSTATE (INTEGER)
#   ZMESSAGECOUNTER (INTEGER)
#   ZREMOVED (INTEGER)
#   ZSESSIONTYPE (INTEGER)
#   ZSPOTLIGHTSTATUS (INTEGER)
#   ZUNREADCOUNT (INTEGER)
#   ZGROUPINFO (INTEGER)
#   ZLASTMESSAGE (INTEGER)
#   ZPROPERTIES (INTEGER)
#   ZLASTMESSAGEDATE (TIMESTAMP)
#   ZLOCATIONSHARINGENDDATE (TIMESTAMP)
#   ZCONTACTIDENTIFIER (VARCHAR)
#   ZCONTACTJID (VARCHAR)
#   ZETAG (VARCHAR)
#   ZLASTMESSAGETEXT (VARCHAR)
#   ZPARTNERNAME (VARCHAR)
#   ZSAVEDINPUT (VARCHAR)
# ----------------------------------------
# Table: ZWAGROUPINFO
# Columns:
#   Z_PK (INTEGER)
#   Z_ENT (INTEGER)
#   Z_OPT (INTEGER)
#   ZSTATE (INTEGER)
#   ZCHATSESSION (INTEGER)
#   ZLASTMESSAGEOWNER (INTEGER)
#   ZCREATIONDATE (TIMESTAMP)
#   ZSUBJECTTIMESTAMP (TIMESTAMP)
#   ZCREATORJID (VARCHAR)
#   ZOWNERJID (VARCHAR)
#   ZPICTUREID (VARCHAR)
#   ZPICTUREPATH (VARCHAR)
#   ZSOURCEJID (VARCHAR)
#   ZSUBJECTOWNERJID (VARCHAR)
# ----------------------------------------
# Table: ZWAGROUPMEMBER
# Columns:
#   Z_PK (INTEGER)
#   Z_ENT (INTEGER)
#   Z_OPT (INTEGER)
#   ZCONTACTABID (INTEGER)
#   ZISACTIVE (INTEGER)
#   ZISADMIN (INTEGER)
#   ZSENDERKEYSENT (INTEGER)
#   ZCHATSESSION (INTEGER)
#   ZRECENTGROUPCHAT (INTEGER)
#   ZCONTACTIDENTIFIER (VARCHAR)
#   ZCONTACTNAME (VARCHAR)
#   ZFIRSTNAME (VARCHAR)
#   ZMEMBERJID (VARCHAR)
# ----------------------------------------
# Table: ZWAGROUPMEMBERSCHANGE
# Columns:
#   Z_PK (INTEGER)
#   Z_ENT (INTEGER)
#   Z_OPT (INTEGER)
#   ZCHANGETYPE (INTEGER)
#   ZCHANGEDATE (TIMESTAMP)
#   ZGROUPJID (VARCHAR)
#   ZMEMBERJIDS (VARCHAR)
#   ZPHASHBEFORECHANGE (VARCHAR)
# ----------------------------------------
# Table: ZWAMEDIAITEM
# Columns:
#   Z_PK (INTEGER)
#   Z_ENT (INTEGER)
#   Z_OPT (INTEGER)
#   ZCLOUDSTATUS (INTEGER)
#   ZFILESIZE (INTEGER)
#   ZMEDIAORIGIN (INTEGER)
#   ZMOVIEDURATION (INTEGER)
#   ZMESSAGE (INTEGER)
#   ZASPECTRATIO (FLOAT)
#   ZHACCURACY (FLOAT)
#   ZLATITUDE (FLOAT)
#   ZLONGITUDE (FLOAT)
#   ZMEDIAURLDATE (TIMESTAMP)
#   ZAUTHORNAME (VARCHAR)
#   ZCOLLECTIONNAME (VARCHAR)
#   ZMEDIALOCALPATH (VARCHAR)
#   ZMEDIAURL (VARCHAR)
#   ZTHUMBNAILLOCALPATH (VARCHAR)
#   ZTITLE (VARCHAR)
#   ZVCARDNAME (VARCHAR)
#   ZVCARDSTRING (VARCHAR)
#   ZXMPPTHUMBPATH (VARCHAR)
#   ZMEDIAKEY (BLOB)
#   ZMETADATA (BLOB)
# ----------------------------------------
# Table: ZWAMESSAGE
# Columns:
#   Z_PK (INTEGER)
#   Z_ENT (INTEGER)
#   Z_OPT (INTEGER)
#   ZCHILDMESSAGESDELIVEREDCOUNT (INTEGER)
#   ZCHILDMESSAGESPLAYEDCOUNT (INTEGER)
#   ZCHILDMESSAGESREADCOUNT (INTEGER)
#   ZDATAITEMVERSION (INTEGER)
#   ZDOCID (INTEGER)
#   ZENCRETRYCOUNT (INTEGER)
#   ZFILTEREDRECIPIENTCOUNT (INTEGER)
#   ZFLAGS (INTEGER)
#   ZGROUPEVENTTYPE (INTEGER)
#   ZISFROMME (INTEGER)
#   ZMESSAGEERRORSTATUS (INTEGER)
#   ZMESSAGESTATUS (INTEGER)
#   ZMESSAGETYPE (INTEGER)
#   ZSORT (INTEGER)
#   ZSPOTLIGHTSTATUS (INTEGER)
#   ZSTARRED (INTEGER)
#   ZCHATSESSION (INTEGER)
#   ZGROUPMEMBER (INTEGER)
#   ZLASTSESSION (INTEGER)
#   ZMEDIAITEM (INTEGER)
#   ZMESSAGEINFO (INTEGER)
#   ZPARENTMESSAGE (INTEGER)
#   ZMESSAGEDATE (TIMESTAMP)
#   ZSENTDATE (TIMESTAMP)
#   ZFROMJID (VARCHAR)
#   ZMEDIASECTIONID (VARCHAR)
#   ZPHASH (VARCHAR)
#   ZPUSHNAME (VARCHAR)
#   ZSTANZAID (VARCHAR)
#   ZTEXT (VARCHAR)
#   ZTOJID (VARCHAR)
# ----------------------------------------
# Table: ZWAMESSAGEDATAITEM
# Columns:
#   Z_PK (INTEGER)
#   Z_ENT (INTEGER)
#   Z_OPT (INTEGER)
#   ZINDEX (INTEGER)
#   ZOWNSTHUMBNAIL (INTEGER)
#   ZTYPE (INTEGER)
#   ZMESSAGE (INTEGER)
#   ZDATE (TIMESTAMP)
#   ZCHATJID (VARCHAR)
#   ZCONTENT1 (VARCHAR)
#   ZCONTENT2 (VARCHAR)
#   ZMATCHEDTEXT (VARCHAR)
#   ZSECTIONID (VARCHAR)
#   ZSENDERJID (VARCHAR)
#   ZSUMMARY (VARCHAR)
#   ZTHUMBNAILPATH (VARCHAR)
#   ZTITLE (VARCHAR)
# ----------------------------------------
# Table: ZWAMESSAGEINFO
# Columns:
#   Z_PK (INTEGER)
#   Z_ENT (INTEGER)
#   Z_OPT (INTEGER)
#   ZMESSAGE (INTEGER)
#   ZRECEIPTINFO (BLOB)
# ----------------------------------------
# Table: ZWAPROFILEPICTUREITEM
# Columns:
#   Z_PK (INTEGER)
#   Z_ENT (INTEGER)
#   Z_OPT (INTEGER)
#   ZREQUESTDATE (TIMESTAMP)
#   ZJID (VARCHAR)
#   ZPATH (VARCHAR)
#   ZPICTUREID (VARCHAR)
# ----------------------------------------
# Table: ZWAPROFILEPUSHNAME
# Columns:
#   Z_PK (INTEGER)
#   Z_ENT (INTEGER)
#   Z_OPT (INTEGER)
#   ZJID (VARCHAR)
#   ZPUSHNAME (VARCHAR)
# ----------------------------------------
# Table: ZWAVCARDMENTION
# Columns:
#   Z_PK (INTEGER)
#   Z_ENT (INTEGER)
#   Z_OPT (INTEGER)
#   ZISFROMME (INTEGER)
#   ZTRUSTEDWHENINDEXED (INTEGER)
#   ZMEDIAITEM (INTEGER)
#   ZDATE (TIMESTAMP)
#   ZSENDERJID (VARCHAR)
#   ZWHATSAPPID (VARCHAR)
# ----------------------------------------
# Table: ZWAZ1PAYMENTTRANSACTION
# Columns:
#   Z_PK (INTEGER)
#   Z_ENT (INTEGER)
#   Z_OPT (INTEGER)
#   ZAMOUNT_1000 (INTEGER)
#   ZSTATUS (INTEGER)
#   ZTYPE (INTEGER)
#   ZTIMESTAMP (TIMESTAMP)
#   ZBANKTRANSACTIONID (VARCHAR)
#   ZCREDENTIALID (VARCHAR)
#   ZCURRENCY (VARCHAR)
#   ZERRORCODE (VARCHAR)
#   ZGROUPJID (VARCHAR)
#   ZMESSAGESTANZAID (VARCHAR)
#   ZRECEIVERJID (VARCHAR)
#   ZSENDERJID (VARCHAR)
#   ZTRANSACTIONID (VARCHAR)
#   ZMETADATA (BLOB)
# ----------------------------------------
# Table: Z_PRIMARYKEY
# Columns:
#   Z_ENT (INTEGER)
#   Z_NAME (VARCHAR)
#   Z_SUPER (INTEGER)
#   Z_MAX (INTEGER)
# ----------------------------------------
# Table: Z_METADATA
# Columns:
#   Z_VERSION (INTEGER)
#   Z_UUID (VARCHAR(255))
#   Z_PLIST (BLOB)
# ----------------------------------------
# Table: Z_MODELCACHE
# Columns:
#   Z_CONTENT (BLOB)
# ----------------------------------------
